# %% [markdown]
# BIG DATA ANALYTICS - Final Project
# NAME : MABLINE ANDREA
# STUDENT ID : 00231505
# GROUP NAME : FP J

# %% [markdown]
# The below  tasks are performed using trial_COVID-19_Hospital_Impact.csv

# %% [markdown]
# Task 1.A. Extract binary features (i.e. a sparse representation of the characteristic
# matrix) per hospital
# For each record, treat the first element as the unique record id. For each of the 108 other
# columns, treat them as a binary feature with an id as string of the form:
# "column_name:value" and add that to a set that represents the values that are "1" in the
# characteristic matrix (every element of the set not present is assumed to be 0).

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder.appName("BinaryFeatureExtraction").getOrCreate()

hospitals_rdd = spark.sparkContext.textFile("/content/trial_COVID-19_Hospital_Impact.csv", 32)

header = hospitals_rdd.first()
header_list = header.split(",")
header_broadcast = spark.sparkContext.broadcast(header_list)

def binary_features_generation(row):
    values = row.split(",")
    if len(values) != len(header_broadcast.value):
        return None
    hospital_pk = values[0]
    features = set()
    for i, value in enumerate(values[1:], start=1):
        value = value.strip()
        if not value:
            continue
        col_name = header_broadcast.value[i]
        feature = f"{col_name}:{value}"
        features.add(feature)
    return (hospital_pk, features)

features_rdd = hospitals_rdd.filter(lambda x: x != header) \
    .map(binary_features_generation) \
    .filter(lambda x: x is not None)

reduced_rdd = features_rdd.reduceByKey(lambda x, y: x.union(y))

target_hospital_pks = {"150034", "50739", "330231", "241326", "070008"}
filtered_rdd = reduced_rdd.filter(lambda x: x[0] in target_hospital_pks)

results = filtered_rdd.collect()
for hospital_pk, features in results:
    print(f"({hospital_pk}, {features})")
with open("output_task_1.txt", "w") as f:
    for hospital_pk, features in results:
        f.write(f"{hospital_pk}, {features}\n")
# Out:
# (070008, {'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'previous_day_total_ED_visits_7_day_sum:323', 'previous_day_admission_adult_covid_suspected_7_day_coverage:6', 'address:201 CHESTNUT HILL ROAD', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'all_adult_hospital_beds_7_day_sum:459', 'previous_day_admission_adult_covid_suspected_7_day_sum:-999999', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_sum:422', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:5', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'total_staffed_adult_icu_beds_7_day_avg:7', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'total_icu_beds_7_day_avg:7', 'city:STAFFORD SPRINGS', 'total_beds_7_day_avg:65.6', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:0', 'total_icu_beds_7_day_sum:42', 'hhs_ids:[C070008-A]', 'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'total_staffed_adult_icu_beds_7_day_sum:42', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:0', 'state:CT', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0', 'collection_week:2020/07/31', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'inpatient_beds_used_covid_7_day_avg:-999999', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0', 'is_metro_micro:true', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:0', 'all_adult_hospital_inpatient_beds_7_day_avg:60.3', 'all_adult_hospital_beds_7_day_avg:65.6', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'fips_code:09013', 'hospital_subtype:Short Term', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:6', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'total_staffed_adult_icu_beds_7_day_coverage:6', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0', 'previous_day_admission_pediatric_covid_confirmed_7_day_coverage:6', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:4', 'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:31.6', 'inpatient_beds_used_7_day_coverage:7', 'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'inpatient_beds_used_7_day_avg:31.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:221', 'inpatient_beds_7_day_sum:422', 'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'all_adult_hospital_beds_7_day_coverage:7', 'icu_patients_confirmed_influenza_7_day_coverage:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0', 'icu_beds_used_7_day_coverage:7', 'total_beds_7_day_coverage:7', 'total_icu_beds_7_day_coverage:6', 'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0', 'staffed_adult_icu_bed_occupancy_7_day_sum:16', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_7_day_sum:0', 'previous_day_admission_adu ...
# (241326, {'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0', 'inpatient_beds_used_7_day_avg:5.1', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0', 'collection_week:2020/08/07', 'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'inpatient_beds_used_7_day_sum:36', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_sum:98', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'state:MN', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:0', 'total_beds_7_day_avg:22', 'inpatient_beds_7_day_avg:14', 'total_icu_beds_7_day_avg:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'hospital_subtype:Critical Access Hospitals', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_avg:14', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'staffed_adult_icu_bed_occupancy_7_day_sum:0', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:4.3', 'total_staffed_adult_icu_beds_7_day_sum:0', 'previous_day_covid_ED_visits_7_day_sum:15', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:0', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:30', 'is_metro_micro:false', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'icu_beds_used_7_day_avg:0', 'inpatient_beds_used_covid_7_day_avg:0', 'all_adult_hospital_beds_7_day_avg:22', 'all_adult_hospital_beds_7_day_sum:154', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_coverage:7', 'fips_code:27153', 'city:LONG PRAIRIE', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0', 'previous_day_total_ED_visits_7_day_sum:92', 'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'inpatient_beds_used_7_day_coverage:7', 'staffed_adult_icu_bed_occupancy_7_day_avg:0', 'total_icu_beds_7_day_coverage:7', 'zip:56347', 'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'all_adult_hospital_beds_7_day_coverage:7', 'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'icu_patients_confirmed_influenza_7_day_coverage:0', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:7', 'hhs_ids:[C241326-A]', 'inpatient_beds_used_covid_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0', 'hospital_name:CENTRACARE HEALTH SYSTEM - LONG PRAIRIE', 'icu_beds_used_7_day_coverage:7', 'total_icu_beds_7_day_sum:0', 'total_beds_7_day_coverage:7', 'ccn:241326', 'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:0', 'icu_beds_used_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_30-39_7_day_ ...
# (150034, {'collection_week:2021/01/22', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:-999999', 'icu_patients_confirmed_influenza_7_day_sum:0', 'icu_beds_used_7_day_sum:112', 'inpatient_beds_used_7_day_sum:1017', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:5', 'total_patients_hospitalized_confirmed_influenza_7_day_avg:0', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'state:IN', 'all_adult_hospital_inpatient_beds_7_day_avg:218', 'total_beds_7_day_sum:2016', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:159', 'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'inpatient_beds_used_7_day_sum:1110', 'previous_day_total_ED_visits_7_day_sum:639', 'inpatient_beds_used_covid_7_day_avg:22.7', 'total_staffed_adult_icu_beds_7_day_avg:20', 'previous_day_admission_adult_covid_confirmed_7_day_sum:14', 'total_icu_beds_7_day_sum:140', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:-999999', 'previous_day_admission_adult_covid_suspected_7_day_sum:30', 'previous_day_admission_influenza_confirmed_7_day_sum:0', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:34', 'total_beds_7_day_avg:288', 'previous_day_total_ED_visits_7_day_sum:519', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_50-59_7_day_sum:-999999', 'inpatient_beds_7_day_sum:1526', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:25', 'icu_beds_used_7_day_avg:16.3', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:4.9', 'total_icu_beds_7_day_avg:20', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg:0', 'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:5', 'icu_patients_confirmed_influenza_7_day_avg:0', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7', 'geocoded_hospital_address:POINT (-87.258916 41.513396)', 'previous_day_admission_adult_covid_confirmed_7_day_sum:7', 'total_patients_hospitalized_confirmed_influenza_7_day_coverage:7', 'all_adult_hospital_inpatient_beds_7_day_sum:1526', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'inpatient_beds_used_7_day_avg:158.6', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:-999999', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:-999999', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:145.3', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:22.6', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:8', 'inpatient_beds_7_day_avg:218', 'ccn:150034', 'previous_day_admission_adult_covid_confirmed_20-29_7_day_sum:-999999', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0', 'is_metro_micro:true', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:4.9', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:83', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:-999999', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:34', 'hospital_subtype:Short Term', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0', 'staffed_adult_icu_bed_o ...
# (330231, {'inpatient_beds_7_day_sum:2344', 'inpatient_beds_7_day_avg:334.9', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'all_adult_hospital_inpatient_beds_7_day_avg:334.9', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:0', 'previous_day_admission_adult_covid_confirmed_18-19_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_7_day_sum:6', 'total_beds_7_day_avg:1045.9', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'previous_day_total_ED_visits_7_day_sum:1213', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:0', 'collection_week:2020/10/30', 'previous_day_covid_ED_visits_7_day_sum:12', 'inpatient_beds_used_covid_7_day_avg:8.1', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:-999999', 'previous_day_admission_adult_covid_confirmed_unknown_7_day_sum:-999999', 'total_staffed_adult_icu_beds_7_day_sum:196', 'fips_code:36081', 'icu_beds_used_7_day_avg:28.3', 'all_adult_hospital_beds_7_day_sum:7321', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:0', 'previous_day_admission_adult_covid_suspected_80+_7_day_sum:0', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'geocoded_hospital_address:POINT (-73.803448 40.717037)', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:146.1', 'total_beds_7_day_sum:7321', 'staffed_icu_adult_patients_confirmed_covid_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage:7', 'inpatient_beds_used_7_day_sum:1023', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg:0', 'previous_day_admission_adult_covid_suspected_18-19_7_day_sum:0', 'zip:11432', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:-999999', 'previous_day_admission_pediatric_covid_suspected_7_day_coverage:7', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum:0', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:57', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:6', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:5.7', 'total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage:0', 'is_metro_micro:true', 'all_adult_hospital_beds_7_day_avg:1045.9', 'previous_day_admission_pediatric_covid_confirmed_7_day_sum:0', 'icu_beds_used_7_day_sum:198', 'hospital_subtype:Short Term', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:0', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:0', 'hhs_ids:[C330231-A]', 'inpatient_beds_used_covid_7_day_sum:57', 'all_adult_hospital_inpatient_beds_7_day_sum:2344', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_30-39_7_day_sum:0', 'address:82-68 164TH STREET', 'previous_day_admission_adult_covid_suspected_20-29_7_day_sum:0', 'inpatient_beds_used_7_day_coverage:7', 'total_icu_beds_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:8.1', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1023', 'previous_day_admission_pediatric_covid_suspected_7_day_sum:0', 'all_adult_hospital_beds_7_day_coverage:7', 'all_adult_hospital_inpatient_bed_occupied_7_day_coverage:7', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:40', 'icu_patients_confirmed_influenza_7_day_coverage:0', 'previous_day_admission_adult_covid_confirmed_7_day_coverage:7', 'staffed_adult_icu_bed_occupancy_7_day_avg:15', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:0', 'icu_beds_used_7_day_coverage:7', 'state:NY', 'hospital_name:QUEENS HOSPITAL CENTER', 'total_beds_7_day_coverage:7', 'total_staffed_adult_icu_beds_7_day_avg:28', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_ ...

# %% [markdown]
# Task 2.B. Minhash
#
# Create a “signature” for each hospital: Use the efficient Minhashing approach to convert the set representation of each hospital into 100 dimensions by using hashes on the set strings. Requirement: Do not store the hashed values of every potential set element in a broadcast variable it will be too large.

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext
import random

spark = SparkSession.builder \
    .appName("MinHashing Hospitals Task 2") \
    .getOrCreate()

sc = spark.sparkContext

num_hashes = 100
max_hash = 2**31 - 1
random.seed(42)
hash_functions = [
    (random.randint(1, max_hash), random.randint(1, max_hash))
    for _ in range(num_hashes)
]

hash_broadcast = sc.broadcast(hash_functions)

def compute_hashes(element, hash_functions):
    return [((a * hash(element) + b) % max_hash) for a, b in hash_functions]

def min_hash_reduce(values):
    return min(values)

hospitals_rdd = spark.sparkContext.textFile("/content/trial_COVID-19_Hospital_Impact.csv", 32)

hospital_rdd = hospitals_rdd.map(lambda line: (
    line.split(",")[0],
    line.split(",")[1:]
))

signature_rdd = hospital_rdd.flatMap(lambda x: [
    ((i, x[0]), compute_hashes(feat, hash_broadcast.value)[i])
    for feat in x[1]
    for i in range(num_hashes)
])

signature_min_rdd = signature_rdd.reduceByKey(lambda x, y: min(x, y))

hospital_signature_rdd = signature_min_rdd.map(lambda x: (x[0][1], (x[0][0], x[1]))) \
    .groupByKey() \
    .mapValues(lambda sig: [val[1] for val in sorted(sig, key=lambda t: t[0])])

hospital_pks = ["150034", "050739", "330231", "241326", "070008"]
result_task_2 = hospital_signature_rdd.filter(lambda x: x[0] in hospital_pks).collect()

for hospital_id, signature in result_task_2:
    print(f"Hospital ID: {hospital_id}")
    print(f"Signature vector: {signature}")
with open("signatures_task_2.txt", "w") as f:
    for hospital_id, signature in result_task_2:
        f.write(f"{hospital_id},{signature}\n")
# Out:
# Hospital ID: 070008
# Signature vector: [10098328, 122102293, 146665953, 3177446, 78838577, 16604389, 96429205, 17215421, 68252794, 37113690, 52881089, 10453654, 3081159, 198198587, 196279117, 145637412, 129264407, 49294848, 56301363, 104715602, 120345011, 11944121, 5431726, 77995789, 100590622, 219494903, 20210338, 22188815, 63521322, 104746197, 93309106, 141500264, 100303012, 88592688, 45229174, 40403739, 149160513, 105422517, 31199168, 55615623, 28956278, 22936120, 13971222, 29886880, 187522122, 196995516, 23117204, 57836919, 11556581, 8007663, 125164560, 119375963, 106112241, 177173260, 48561495, 16568724, 102837489, 28376083, 35140049, 79230628, 128324738, 28893119, 97876829, 2763653, 24691984, 120125831, 442019, 1234711, 118857525, 98467984, 60127955, 21308841, 21278276, 95599903, 122891732, 176865201, 48671859, 56969213, 69243352, 346161961, 35324216, 49181513, 109773004, 78156259, 38114121, 41953466, 52995789, 39133655, 107189496, 40050716, 8470306, 39434150, 128842773, 269322195, 21338449, 23613623, 255481272, 75991687, 21436612, 42609393]
# Hospital ID: 241326
# Signature vector: [17276938, 111738583, 114139439, 174027777, 12478141, 85968985, 5548789, 232805706, 68252794, 201209006, 48970769, 80934318, 3081159, 121478617, 63275375, 87567217, 81644613, 99385801, 156767945, 116490962, 241376967, 40648072, 221092898, 77995789, 44051445, 219494903, 16706904, 22188815, 54169409, 7952960, 93309106, 261895281, 33689398, 69603581, 48357095, 57260896, 111174447, 55546316, 140732965, 41047405, 15014845, 22117782, 13971222, 13152725, 20886487, 87383679, 219338553, 155716992, 48218863, 6534796, 78926409, 45706354, 11212130, 9708246, 48561495, 18710165, 51427224, 72292262, 81189542, 32908488, 92548391, 39604421, 129296105, 144166238, 30628702, 19351330, 442019, 65649293, 104100104, 96850892, 134104036, 1607528, 160650789, 95599903, 8955896, 104715328, 135837454, 245409190, 27989400, 23225644, 98058077, 8019002, 3298979, 102607388, 164589322, 144763960, 78918740, 39133655, 31358838, 17898449, 327497860, 39434150, 100901819, 13420719, 19992718, 275010204, 34020517, 15719788, 236520132, 136765046]
# Hospital ID: 150034
# Signature vector: [4464876, 20152766, 38909307, 88611788, 20100756, 3937070, 60306524, 18894015, 68252794, 9491021, 5135806, 10453654, 3081159, 30659335, 63819923, 35143285, 105931421, 18911124, 56301363, 43737331, 120345011, 45468132, 5431726, 50731918, 4105279, 26815828, 20210338, 22188815, 14283398, 49584574, 64407647, 47560211, 33689398, 18471244, 279652, 36728101, 40198565, 44266474, 7359673, 61930723, 16096228, 17801760, 10014377, 200653959, 78048654, 8368244, 38543070, 55906799, 32492566, 24538227, 270163, 28332404, 27705772, 54864652, 44031037, 18710165, 51427224, 28376083, 10085335, 32908488, 52967505, 26023573, 98867105, 34624610, 30628702, 4966538, 442019, 8954486, 2286842, 142138945, 190801035, 21308841, 21278276, 2874988, 11533374, 9807405, 46445145, 45912035, 77058389, 29027360, 12993544, 722764, 10568371, 28710511, 3596589, 41953466, 22462455, 31925183, 6647361, 99361122, 8470306, 13535302, 19181335, 99089079, 1262874, 39869040, 27773434, 164458328, 11789811, 11617624]
# Hospital ID: 050739
# Signature vector: [8497116, 26026166, 19107243, 7446563, 18014583, 26716827, 127985619, 30619820, 156390371, 15788036, 15155386, 31189223, 3081159, 4069718, 77107300, 22728783, 4252768, 79513136, 2340990, 116490962, 22535002, 30661489, 5431726, 59810553, 28456843, 26815828, 20210338, 22188815, 54169409, 79950144, 19529497, 31929008, 33689398, 80119985, 4357831, 19030552, 10199538, 736378, 78151845, 81513171, 21478564, 92284906, 13971222, 138143316, 35634120, 59473630, 38534336, 598767, 29301590, 33419118, 18531716, 64056103, 17582353, 207319731, 48561495, 1057496, 58334708, 28376083, 15473274, 1960615, 1194995, 47068849, 33297867, 26232671, 24299197, 30382243, 442019, 1144811, 21913430, 76323571, 6453798, 19461314, 6591225, 10070046, 24464110, 16882452, 79241806, 7172398, 77058389, 18293612, 51015754, 722764, 3635074, 687014, 43985201, 2875884, 78918740, 39133655, 9609948, 159020817, 8470306, 39434150, 12677165, 20671271, 7871396, 4547789, 33619599, 5309861, 11789811, 54484707]
# Hospital ID: 330231
# Signature vector: [92944157, 39797752, 176013954, 16307511, 20100756, 26056216, 35582314, 41535727, 60399172, 58714199, 171186439, 41380439, 3081159, 29539542, 68487306, 54854643, 82546843, 42659274, 16309517, 116490962, 120345011, 29349827, 5431726, 77995789, 103548739, 78016955, 12356109, 22188815, 86032493, 31662887, 92567996, 17835074, 34782053, 56945338, 26656564, 21263804, 16840935, 64612522, 116567043, 40868666, 16096228, 26435671, 13971222, 140513731, 90031718, 60505591, 55883187, 6374966, 132741211, 23467763, 44861560, 31744786, 9648516, 122173659, 44031037, 18710165, 22842899, 28376083, 35140049, 11830931, 1546149, 30591209, 147135793, 102227892, 30628702, 4966538, 442019, 22930432, 61077995, 118664243, 11500386, 3935381, 135142696, 95599903, 52362581, 59860832, 81942225, 163870253, 51107949, 101759909, 37180915, 49181513, 52552331, 8755006, 46688378, 25433245, 188983795, 32849015, 45517603, 252390673, 8470306, 100678, 96399512, 162985386, 84632451, 20884014, 76118526, 7479759, 82918147, 85955760]

# %%
hospitals_rdd = spark.sparkContext.textFile("/content/trial_COVID-19_Hospital_Impact.csv", 32)
print(hospitals_rdd.take(10))
# Out:
# ['hospital_pk,collection_week,state,ccn,hospital_name,address,city,zip,hospital_subtype,fips_code,is_metro_micro,total_beds_7_day_avg,all_adult_hospital_beds_7_day_avg,all_adult_hospital_inpatient_beds_7_day_avg,inpatient_beds_used_7_day_avg,all_adult_hospital_inpatient_bed_occupied_7_day_avg,inpatient_beds_used_covid_7_day_avg,total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg,total_adult_patients_hospitalized_confirmed_covid_7_day_avg,total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg,total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg,inpatient_beds_7_day_avg,total_icu_beds_7_day_avg,total_staffed_adult_icu_beds_7_day_avg,icu_beds_used_7_day_avg,staffed_adult_icu_bed_occupancy_7_day_avg,staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg,staffed_icu_adult_patients_confirmed_covid_7_day_avg,total_patients_hospitalized_confirmed_influenza_7_day_avg,icu_patients_confirmed_influenza_7_day_avg,total_patients_hospitalized_confirmed_influenza_and_covid_7_day_avg,total_beds_7_day_sum,all_adult_hospital_beds_7_day_sum,all_adult_hospital_inpatient_beds_7_day_sum,inpatient_beds_used_7_day_sum,all_adult_hospital_inpatient_bed_occupied_7_day_sum,inpatient_beds_used_covid_7_day_sum,total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum,total_adult_patients_hospitalized_confirmed_covid_7_day_sum,total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum,total_pediatric_patients_hospitalized_confirmed_covid_7_day_sum,inpatient_beds_7_day_sum,total_icu_beds_7_day_sum,total_staffed_adult_icu_beds_7_day_sum,icu_beds_used_7_day_sum,staffed_adult_icu_bed_occupancy_7_day_sum,staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum,staffed_icu_adult_patients_confirmed_covid_7_day_sum,total_patients_hospitalized_confirmed_influenza_7_day_sum,icu_patients_confirmed_influenza_7_day_sum,total_patients_hospitalized_confirmed_influenza_and_covid_7_day_sum,total_beds_7_day_coverage,all_adult_hospital_beds_7_day_coverage,all_adult_hospital_inpatient_beds_7_day_coverage,inpatient_beds_used_7_day_coverage,all_adult_hospital_inpatient_bed_occupied_7_day_coverage,inpatient_beds_used_covid_7_day_coverage,total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage,total_adult_patients_hospitalized_confirmed_covid_7_day_coverage,total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_coverage,total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage,inpatient_beds_7_day_coverage,total_icu_beds_7_day_coverage,total_staffed_adult_icu_beds_7_day_coverage,icu_beds_used_7_day_coverage,staffed_adult_icu_bed_occupancy_7_day_coverage,staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_coverage,staffed_icu_adult_patients_confirmed_covid_7_day_coverage,total_patients_hospitalized_confirmed_influenza_7_day_coverage,icu_patients_confirmed_influenza_7_day_coverage,total_patients_hospitalized_confirmed_influenza_and_covid_7_day_coverage,previous_day_admission_adult_covid_confirmed_7_day_sum,previous_day_admission_adult_covid_confirmed_18-19_7_day_sum,previous_day_admission_adult_covid_confirmed_20-29_7_day_sum,previous_day_admission_adult_covid_confirmed_30-39_7_day_sum,previous_day_admission_adult_covid_confirmed_40-49_7_day_sum,previous_day_admission_adult_covid_confirmed_50-59_7_day_sum,previous_day_admission_adult_covid_confirmed_60-69_7_day_sum,previous_day_admission_adult_covid_confirmed_70-79_7_day_sum,previous_day_admission_adult_covid_confirmed_80+_7_day_sum,previous_day_admission_adult_covid_confirmed_unknown_7_day_sum,previous_day_admission_pediatric_covid_confirmed_7_day_sum,previous_day_covid_ED_visits_7_day_sum,previous_day_admission_adult_covid_suspected_7_day_sum,previous_day_admission_adult_covid_suspected_18-19_7_day_sum,previous_day_admission_adult_covid_suspected_20-29_7_day_sum,previous_day_admission_adult_covid_suspected_30-39_7_day_sum,previous_day_admission_adult_covid_s ...

# %% [markdown]
# C. Find similar pairs using LSH
# Run LSH to find approximately 20 candidates that are most similar to hospitals: 150034, 50739,
# 330231,241326, 70008. From the perspective of LSH, each hospital is a column with each row
# being a value of the signatures. Tweak bands and rows per band in order to get approximately 20
# candidates (i.e. anything between 10 to 30 candidates per hospital is ok).

# %%
from pyspark import SparkConf, SparkContext
from itertools import combinations
from datetime import datetime
import sys

APP_NAME = 'LSH'
SPLITTER = ','
BANDS = 5
ROWS = 4
NUM_CANDIDATES = (10, 30)
TARGET_HOSPITALS = {"150034", "50739", "330231", "241326", "070008"}
DEBUG = 0
PRINT_TIME = True
INPUT_FILE = '/content/trial_COVID-19_Hospital_Impact.csv'
OUTPUT_FILE = 'output_task_3.txt'

def getInputData(filename):
    _data = []
    try:
        with open(filename, 'r') as _fp:
            first_line = True
            for _each_line in _fp:
                if first_line:
                    first_line = False
                    continue
                _row = _each_line.strip().split(SPLITTER)
                if len(_row) > 1:
                    hospital_id = _row[0]
                    try:
                        numeric_values = [
                            int(float(x)) for x in _row[1:]
                            if x.strip().replace('.', '', 1).lstrip('-').isdigit()
                        ]
                        while len(numeric_values) < 100:
                            numeric_values.append(0)
                        _data.append((hospital_id, numeric_values[:100]))
                    except ValueError as e:
                        print(f"Skipping invalid row: {_row} -> Error: {e}")
        return _data
    except IOError as _err:
        print(f'File error: {_err}')
        exit()

def setOutputData(filename, results):
    with open(filename, 'w') as f:
        for target, matches in results.items():
            f.write(f"Target Hospital: {target}\n")
            seen = set()
            for match in sorted(matches, key=lambda x: -x[2]):
                matched_hospital = match[1]
                if matched_hospital in seen:
                    continue
                seen.add(matched_hospital)
                similarity = match[2]
                signature = match[3] if len(match) > 3 else []
                f.write(f"  Matched Hospital: {matched_hospital}, Jaccard Similarity: {similarity:.4f}, Signature: {signature[:10]}\n")

def jaccard_similarity(sig1, sig2):
    intersection = sum(1 for a, b in zip(sig1, sig2) if a == b)
    union = len(sig1)
    return intersection / union

def divide_into_bands(signature, bands, rows):
    for band in range(bands):
        start = band * rows
        end = start + rows
        yield band, tuple(signature[start:end])

if __name__ == "__main__":
    if PRINT_TIME:
        print(f'LSH=>Start=>{datetime.now()}')
    conf = SparkConf().setAppName(APP_NAME).setMaster("local[*]")
    sc = SparkContext(conf=conf)

    try:
        data_list = getInputData(INPUT_FILE)
        if not data_list:
            raise ValueError("No valid data loaded from the input file.")
    except Exception as e:
        print(f"Error loading input file: {e}")
        sc.stop()
        exit()

    rdd = sc.parallelize(data_list)

    def create_bands(hospital):
        hospital_id, signature = hospital
        bands = []
        for band, band_signature in divide_into_bands(signature, BANDS, ROWS):
            bands.append(((band, hash(band_signature)), hospital_id))
        return bands

    band_rdd = rdd.flatMap(create_bands)

    def candidate_pairs_generation(bucket):
        hospitals = list(bucket)
        for i, j in combinations(hospitals, 2):
            yield (i, j)

    candidates_rdd = band_rdd.groupByKey() \
        .filter(lambda x: len(x[1]) > 1) \
        .flatMap(lambda x: candidate_pairs_generation(x[1])).distinct()

    hospital_dict = dict(rdd.collect())

    def compute_similarity(pair):
        h1, h2 = pair
        if h1 in TARGET_HOSPITALS or h2 in TARGET_HOSPITALS:
            sig1 = hospital_dict[h1]
            sig2 = hospital_dict[h2]
            similarity = jaccard_similarity(sig1, sig2)
            return h1, h2, similarity, sig2[:10]
        return None

    results_rdd = candidates_rdd.map(compute_similarity).filter(lambda x: x is not None)

    def limit_candidates(results):
        sorted_results = sorted(results, key=lambda x: -x[2])
        return sorted_results[:NUM_CANDIDATES[1]]

    grouped_results = results_rdd.map(lambda x: (x[0] if x[0] in TARGET_HOSPITALS else x[1], x)) \
        .groupByKey() \
        .mapValues(limit_candidates).collectAsMap()

    print("Top Matches for Target Hospitals:")
    for target, matches in grouped_results.items():
        print(f"Target Hospital: {target}")
        seen = set()
        for match in sorted(matches, key=lambda x: -x[2]):
            matched_hospital = match[1]
            if matched_hospital in seen:
                continue
            seen.add(matched_hospital)
            print(f"  Matched Hospital: {matched_hospital}, Jaccard Similarity: {match[2]:.4f}, Signature: {match[3]}")

    setOutputData(OUTPUT_FILE, grouped_results)

    if PRINT_TIME:
        print(f'LSH=>Finish=>{datetime.now()}')
    sc.stop()
# Out:
# LSH=>Start=>2024-12-17 20:17:51.698452
# Top Matches for Target Hospitals:
# Target Hospital: 150034
#   Matched Hospital: 150034, Jaccard Similarity: 1.0000, Signature: [150034, 46342, 18089, 288, 218, 218, 158, 158, 22, 22]
#   Matched Hospital: 250019, Jaccard Similarity: 0.6500, Signature: [250019, 39502, 28047, 252, 244, 218, 189, 189, 22, 22]
#   Matched Hospital: 370023, Jaccard Similarity: 0.6500, Signature: [370023, 73533, 40137, 77, 77, 58, 58, 58, 22, 22]
#   Matched Hospital: 420068, Jaccard Similarity: 0.6100, Signature: [420068, 29115, 45075, 207, 207, 162, 128, 128, 4, 4]
#   Matched Hospital: 100254, Jaccard Similarity: 0.6000, Signature: [100254, 32308, 12073, 310, 302, 258, 202, 201, 15, 15]
#   Matched Hospital: 250082, Jaccard Similarity: 0.5900, Signature: [250082, 38704, 28151, 120, 120, 120, 88, 88, 7, 7]
#   Matched Hospital: 340070, Jaccard Similarity: 0.5800, Signature: [340070, 27216, 37001, 238, 175, 175, 128, 128, 23, 23]
#   Matched Hospital: 010144, Jaccard Similarity: 0.5200, Signature: [10144, 36608, 1097, 332, 332, 300, 236, 236, 36, 36]
#   Matched Hospital: 050124, Jaccard Similarity: 0.3300, Signature: [50124, 91208, 6037, 174, 128, 128, 59, 59, 11, 11]
#   Matched Hospital: 050112, Jaccard Similarity: 0.2800, Signature: [50112, 90404, 6037, 333, 271, 243, 218, 205, 10, 9]
#   Matched Hospital: 520083, Jaccard Similarity: 0.2300, Signature: [520083, 53715, 55025, 298, 279, 277, 289, 272, 11, 11]
# Target Hospital: 241326
#   Matched Hospital: 241326, Jaccard Similarity: 0.8700, Signature: [241326, 56347, 27153, 22, 22, 14, 5, 4, 0, 0]
# Target Hospital: 070008
#   Matched Hospital: 070008, Jaccard Similarity: 0.6900, Signature: [70008, 6076, 9013, 65, 65, 60, 31, 31, -999999, -999999]
# Target Hospital: 330231
#   Matched Hospital: 400021, Jaccard Similarity: 0.6000, Signature: [400021, 683, 72125, 166, 155, 132, 86, 84, 8, 8]
#   Matched Hospital: 390066, Jaccard Similarity: 0.5900, Signature: [390066, 17042, 42075, 159, 159, 159, 82, 82, 8, 8]
#   Matched Hospital: 460051, Jaccard Similarity: 0.5300, Signature: [460051, 84088, 49035, 305, 305, 119, 113, 113, 8, 8]
# LSH=>Finish=>2024-12-17 20:17:58.138818

# %% [markdown]
# Task 1.A. Extract binary features (i.e. a sparse representation of the characteristic
# matrix) per hospital
# For each record, treat the first element as the unique record id. For each of the 108 other
# columns, treat them as a binary feature with an id as string of the form:
# "column_name:value" and add that to a set that represents the values that are "1" in the
# characteristic matrix (every element of the set not present is assumed to be 0) : using test_COVID-19_Hospital_Impact.csv

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder.appName("BinaryFeatureExtraction").getOrCreate()

hospitals_rdd = spark.sparkContext.textFile("/content/test_COVID-19_Hospital_Impact.csv", 32)

header = hospitals_rdd.first()
header_list = header.split(",")
header_broadcast = spark.sparkContext.broadcast(header_list)

def binary_features_generation(row):
    values = row.split(",")
    if len(values) != len(header_broadcast.value):
        return None
    hospital_pk = values[0]
    features = set()
    for i, value in enumerate(values[1:], start=1):
        value = value.strip()
        if not value:
            continue
        col_name = header_broadcast.value[i]
        feature = f"{col_name}:{value}"
        features.add(feature)
    return (hospital_pk, features)

features_rdd = hospitals_rdd.filter(lambda x: x != header) \
    .map(binary_features_generation) \
    .filter(lambda x: x is not None)

reduced_rdd = features_rdd.reduceByKey(lambda x, y: x.union(y))

target_hospital_pks = {"150034", "50739", "330231", "241326", "070008"}
filtered_rdd = reduced_rdd.filter(lambda x: x[0] in target_hospital_pks)

results = filtered_rdd.collect()
for hospital_pk, features in results:
    print(f"({hospital_pk}, {features})")
with open("output_task.txt", "w") as f:
    for hospital_pk, features in results:
        f.write(f"{hospital_pk}, {features}\n")
# Out:
# (070008, {'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:41', 'inpatient_beds_used_7_day_avg:30.1', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:23', 'previous_day_admission_adult_covid_suspected_7_day_sum:13', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:70', 'previous_day_admission_adult_covid_suspected_unknown_7_day_sum:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_sum:9', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:34', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:21', 'hospital_name:JOHNSON MEMORIAL HOSPITAL', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:30', 'inpatient_beds_used_7_day_avg:35.3', 'collection_week:2022/02/25', 'previous_day_covid_ED_visits_7_day_sum:184', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:240', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:27.3', 'inpatient_beds_used_covid_7_day_sum:32', 'inpatient_beds_7_day_avg:47.9', 'inpatient_beds_used_7_day_avg:33.3', 'inpatient_beds_7_day_sum:345', 'inpatient_beds_used_7_day_sum:164', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:38', 'inpatient_beds_used_7_day_avg:32.6', 'collection_week:2021/08/13', 'inpatient_beds_used_7_day_sum:247', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:-999999', 'inpatient_beds_used_covid_7_day_avg:11.4', 'all_adult_hospital_beds_7_day_sum:382', 'collection_week:2021/05/28', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:208', 'previous_day_total_ED_visits_7_day_sum:354', 'total_beds_7_day_sum:330', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:18', 'collection_week:2021/10/15', 'inpatient_beds_used_7_day_avg:28', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'collection_week:2021/12/24', 'all_adult_hospital_beds_7_day_avg:65.6', 'collection_week:2021/03/12', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:25', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:-999999', 'staffed_adult_icu_bed_occupancy_7_day_sum:40', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:23.9', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:-999999', 'total_beds_7_day_sum:422', 'inpatient_beds_used_covid_7_day_sum:21', 'inpatient_beds_used_covid_7_day_sum:44', 'all_adult_hospital_inpatient_beds_7_day_avg:52', 'previous_day_admission_adult_covid_suspected_7_day_sum:8', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:4', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:10', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:25', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:80', 'collection_week:2021/12/10', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:0', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:214', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:32', 'previous_day_covid_ED_visits_7_day_sum:61', 'inpatient_beds_used_7_day_avg:26.4', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:27', 'total_icu_beds_7_day_sum:53', 'staffed_adult_icu_bed_occupancy_7_day_sum:33', 'all_adult_hospital_beds_7_day_avg:49.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:34.4', 'icu_beds_used_7_day_sum:28', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:6', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:221', 'inpatient_beds_used_7_day_sum:248', 'previous_day_total_ED_visits_7_day_sum:388', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'collection_week:2021/02/05', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:205', 'staffed_adult_icu_bed_occupancy_7_day_avg:4.7', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:4', 'inpatient_beds_used_7_day_sum:259', 'previous_day_covid_ED_visits_7_day_sum:52', 'inpatient_beds_used_covid_7_day_sum:50', 'total_adult_pati ...
# (241326, {'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:23', 'inpatient_beds_used_7_day_avg:7.7', 'previous_day_covid_ED_visits_7_day_sum:26', 'collection_week:2022/02/25', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:58', 'previous_day_total_ED_visits_7_day_sum:52', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:11.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:56', 'previous_day_covid_ED_visits_7_day_sum:7', 'previous_day_total_ED_visits_7_day_sum:86', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:6.6', 'inpatient_beds_7_day_sum:98', 'inpatient_beds_7_day_sum:94', 'collection_week:2021/08/13', 'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:-999999', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:7.3', 'all_adult_hospital_beds_7_day_sum:148', 'total_staffed_adult_icu_beds_7_day_avg:0', 'collection_week:2021/05/28', 'previous_day_total_ED_visits_7_day_sum:72', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:33', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:18', 'collection_week:2021/10/15', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:0', 'all_adult_hospital_inpatient_beds_7_day_sum:63', 'collection_week:2021/12/24', 'all_adult_hospital_beds_7_day_avg:18.9', 'all_adult_hospital_beds_7_day_avg:21.2', 'collection_week:2021/03/12', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:25', 'total_beds_7_day_sum:198', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:8.9', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:-999999', 'total_beds_7_day_avg:19.7', 'inpatient_beds_7_day_sum:79', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:10', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:25', 'collection_week:2021/12/10', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:0', 'all_adult_hospital_inpatient_beds_7_day_sum:69', 'all_adult_hospital_inpatient_beds_7_day_sum:90', 'total_beds_7_day_avg:19.9', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:42', 'total_beds_7_day_sum:136', 'inpatient_beds_7_day_avg:7.7', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:25', 'all_adult_hospital_inpatient_beds_7_day_sum:86', 'all_adult_hospital_beds_7_day_avg:21.3', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:5.6', 'all_adult_hospital_beds_7_day_avg:22', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'all_adult_hospital_beds_7_day_sum:132', 'collection_week:2021/02/05', 'all_adult_hospital_inpatient_beds_7_day_avg:8.9', 'previous_day_total_ED_visits_7_day_sum:109', 'total_pediatric_patients_hospitalized_confirmed_covid_7_day_coverage:7', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:0', 'collection_week:2020/12/11', 'total_beds_7_day_sum:127', 'inpatient_beds_used_7_day_avg:8.7', 'collection_week:2021/07/16', 'collection_week:2022/02/18', 'total_patients_hospitalized_confirmed_influenza_7_day_sum:0', 'collection_week:2021/01/15', 'inpatient_beds_used_7_day_avg:6.1', 'inpatient_beds_7_day_avg:15.9', 'collection_week:2021/03/05', 'collection_week:2021/11/19', 'previous_day_covid_ED_visits_7_day_sum:22', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:9.3', 'all_adult_hospital_inpatient_beds_7_day_avg:12.9', 'inpatient_beds_used_7_day_avg:6.7', 'collection_week:2021/04/02', 'city:LONG PRAIRIE', 'inpatient_beds_used_7_day_avg:9.9', 'inpatient_beds_used_7_day_sum:75', 'previous_day_total_ED_visits_7_day_sum:92', 'inpatient_beds_7_day_avg:12.7', 'total_beds_7_day_sum:138', 'previous_day_admission_adult_covid_suspected_7_day_sum:4', 'inpatient_beds_used_covid_7_day_sum:9', 'inpatient_beds_used_7_day_sum:46', 'collection_week:2022/01/14', 'total_beds_7_day_sum:141', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:43', 'inpatient_beds_used_7_day_avg:7', 'all_adult_hospital_inpatient_beds_7_day_avg:11.4', 'previous_day_admission_pediatric_covid_susp ...
# (150034, {'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:10.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:143.9', 'all_adult_hospital_beds_7_day_sum:956', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:16.4', 'previous_day_covid_ED_visits_7_day_sum:184', 'previous_day_covid_ED_visits_7_day_sum:38', 'staffed_adult_icu_bed_occupancy_7_day_avg:10.6', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:57', 'total_staffed_adult_icu_beds_7_day_avg:13', 'icu_beds_used_7_day_avg:16', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:45', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:342', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:9.1', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:25', 'inpatient_beds_used_7_day_avg:136.7', 'inpatient_beds_used_covid_7_day_avg:13.4', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:32.7', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:10.9', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:5', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:38', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:4', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:4.1', 'previous_day_covid_ED_visits_7_day_sum:159', 'all_adult_hospital_beds_7_day_avg:128.4', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:138.1', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:4', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:6', 'staffed_adult_icu_bed_occupancy_7_day_sum:123', 'inpatient_beds_used_7_day_sum:1058', 'total_staffed_adult_icu_beds_7_day_sum:140', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:4.6', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:29', 'collection_week:2021/01/15', 'collection_week:2021/03/05', 'previous_day_covid_ED_visits_7_day_sum:29', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1072', 'all_adult_hospital_inpatient_beds_7_day_sum:912', 'collection_week:2021/04/02', 'previous_day_covid_ED_visits_7_day_sum:135', 'total_beds_7_day_avg:123.3', 'previous_day_admission_adult_covid_suspected_7_day_sum:7', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:14', 'all_adult_hospital_beds_7_day_avg:123.3', 'inpatient_beds_used_7_day_sum:1016', 'inpatient_beds_used_covid_7_day_sum:90', 'previous_day_admission_adult_covid_confirmed_80+_7_day_sum:12', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:14', 'all_adult_hospital_beds_7_day_sum:993', 'inpatient_beds_7_day_avg:136.6', 'inpatient_beds_used_covid_7_day_avg:43', 'previous_day_covid_ED_visits_7_day_sum:89', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:16.6', 'total_staffed_adult_icu_beds_7_day_avg:14.9', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:-999999', 'previous_day_covid_ED_visits_7_day_sum:172', 'all_adult_hospital_inpatient_beds_7_day_sum:972', 'collection_week:2020/08/28', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:5.1', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:132.9', 'staffed_adult_icu_bed_occupancy_7_day_avg:12.7', 'icu_beds_used_7_day_sum:76', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:24.3', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:50', 'previous_day_covid_ED_visits_7_day_sum:144', 'inpatient_beds_used_7_day_avg:144.1', 'inpatient_beds_used_7_day_avg:150.6', 'inpatient_beds_used_covid_7_day_avg:6.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:154.6', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:61', 'previous_day_covid_ED_visits_7_day_sum:110', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:4.6', 'inpatient_beds_used_c ...
# (330231, {'all_adult_hospital_beds_7_day_avg:1162', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:87.7', 'inpatient_beds_used_covid_7_day_avg:60.1', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:16.4', 'previous_day_covid_ED_visits_7_day_sum:38', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1147', 'staffed_adult_icu_bed_occupancy_7_day_avg:24.7', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1184', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:71', 'inpatient_beds_used_7_day_sum:1534', 'total_beds_7_day_avg:619', 'all_adult_hospital_beds_7_day_avg:1206.6', 'inpatient_beds_used_7_day_avg:171.3', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:57', 'all_adult_hospital_inpatient_bed_occupied_7_day_avg:164.3', 'inpatient_beds_7_day_avg:280', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:45', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1334', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:703', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:9.1', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:25', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:10.9', 'total_beds_7_day_sum:4421', 'previous_day_admission_adult_covid_suspected_60-69_7_day_sum:5', 'inpatient_beds_used_7_day_sum:1551', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:38', 'inpatient_beds_7_day_avg:274', 'previous_day_admission_adult_covid_confirmed_50-59_7_day_sum:4', 'previous_day_covid_ED_visits_7_day_sum:61', 'icu_beds_used_7_day_sum:145', 'inpatient_beds_7_day_sum:1725', 'staffed_icu_adult_patients_confirmed_covid_7_day_avg:4.1', 'icu_beds_used_7_day_avg:31.3', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:10', 'previous_day_admission_adult_covid_confirmed_70-79_7_day_sum:4', 'total_beds_7_day_sum:4438', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:321', 'inpatient_beds_7_day_sum:1928', 'icu_beds_used_7_day_avg:33.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1177', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum:48', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg:4.6', 'all_adult_hospital_inpatient_bed_occupied_7_day_sum:1093', 'icu_beds_used_7_day_sum:211', 'collection_week:2021/01/15', 'inpatient_beds_7_day_avg:410.6', 'collection_week:2021/03/05', 'icu_beds_used_7_day_avg:28.7', 'inpatient_beds_used_7_day_sum:1495', 'previous_day_covid_ED_visits_7_day_sum:29', 'total_staffed_adult_icu_beds_7_day_sum:195', 'collection_week:2021/04/02', 'inpatient_beds_used_7_day_avg:208.1', 'previous_day_admission_adult_covid_suspected_7_day_sum:7', 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum:14', 'all_adult_hospital_inpatient_beds_7_day_avg:415.4', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:31.1', 'all_adult_hospital_beds_7_day_sum:3491', 'previous_day_admission_adult_covid_confirmed_60-69_7_day_sum:14', 'inpatient_beds_used_covid_7_day_sum:327', 'all_adult_hospital_beds_7_day_sum:8430', 'previous_day_total_ED_visits_7_day_sum:1511', 'all_adult_hospital_beds_7_day_sum:3965', 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum:254', 'inpatient_beds_used_covid_7_day_avg:43', 'total_adult_patients_hospitalized_confirmed_covid_7_day_avg:5.3', 'icu_beds_used_7_day_avg:20.3', 'all_adult_hospital_inpatient_beds_7_day_avg:468.6', 'previous_day_admission_adult_covid_suspected_40-49_7_day_sum:-999999', 'inpatient_beds_used_7_day_sum:1205', 'icu_beds_used_7_day_sum:195', 'collection_week:2020/08/28', 'staffed_adult_icu_bed_occupancy_7_day_coverage:7', 'total_beds_7_day_sum:4390', 'inpatient_beds_used_covid_7_day_avg:20.4', 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg:37.1', 'staffed_adult_icu_bed_occupancy_7_day_avg:12.7', 'total_adult_patients_hospitalized ...

# %% [markdown]
# Task 2.B. Minhash
#
# Create a “signature” for each hospital: Use the efficient Minhashing approach to convert the set representation of each hospital into 100 dimensions by using hashes on the set strings. Requirement: Do not store the hashed values of every potential set element in a broadcast variable it will be too large.

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext
import random

spark = SparkSession.builder \
    .appName("MinHashing Hospitals Task 2") \
    .getOrCreate()

sc = spark.sparkContext

num_hashes = 100
max_hash = 2**31 - 1
random.seed(42)
hash_functions = [
    (random.randint(1, max_hash), random.randint(1, max_hash))
    for _ in range(num_hashes)
]

hash_broadcast = sc.broadcast(hash_functions)

def compute_hashes(element, hash_functions):
    return [((a * hash(element) + b) % max_hash) for a, b in hash_functions]

def min_hash_reduce(values):
    return min(values)

hospitals_rdd = spark.sparkContext.textFile("/content/test_COVID-19_Hospital_Impact.csv", 32)

hospital_rdd = hospitals_rdd.map(lambda line: (
    line.split(",")[0],
    line.split(",")[1:]
))

signature_rdd = hospital_rdd.flatMap(lambda x: [
    ((i, x[0]), compute_hashes(feat, hash_broadcast.value)[i])
    for feat in x[1]
    for i in range(num_hashes)
])

signature_min_rdd = signature_rdd.reduceByKey(lambda x, y: min(x, y))

hospital_signature_rdd = signature_min_rdd.map(lambda x: (x[0][1], (x[0][0], x[1]))) \
    .groupByKey() \
    .mapValues(lambda sig: [val[1] for val in sorted(sig, key=lambda t: t[0])])

hospital_pks = ["150034", "050739", "330231", "241326", "070008"]
result_task_3 = hospital_signature_rdd.filter(lambda x: x[0] in hospital_pks).collect()

for hospital_id, signature in result_task_2:
    print(f"Hospital ID: {hospital_id}")
    print(f"Signature vector: {signature}")
with open("signatures_task.txt", "w") as f:
    for hospital_id, signature in result_task_3:
        f.write(f"{hospital_id},{signature}\n")

# %% [markdown]
# C. Find similar pairs using LSH
# Run LSH to find approximately 20 candidates that are most similar to hospitals: 150034, 50739,
# 330231,241326, 70008. From the perspective of LSH, each hospital is a column with each row
# being a value of the signatures. Tweak bands and rows per band in order to get approximately 20
# candidates (i.e. anything between 10 to 30 candidates per hospital is ok).

# %%
from pyspark import SparkConf, SparkContext
from itertools import combinations
from datetime import datetime
import sys

APP_NAME = 'LSH'
SPLITTER = ','
BANDS = 5
ROWS = 4
NUM_CANDIDATES = (10, 30)
TARGET_HOSPITALS = {"150034", "50739", "330231", "241326", "070008"}
DEBUG = 0
PRINT_TIME = True
INPUT_FILE = '/content/test_COVID-19_Hospital_Impact.csv'
OUTPUT_FILE = 'output_task.txt'

def getInputData(filename):
    _data = []
    try:
        with open(filename, 'r') as _fp:
            first_line = True
            for _each_line in _fp:
                if first_line:
                    first_line = False
                    continue
                _row = _each_line.strip().split(SPLITTER)
                if len(_row) > 1:
                    hospital_id = _row[0]
                    try:
                        numeric_values = [
                            int(float(x)) for x in _row[1:]
                            if x.strip().replace('.', '', 1).lstrip('-').isdigit()
                        ]
                        while len(numeric_values) < 100:
                            numeric_values.append(0)
                        _data.append((hospital_id, numeric_values[:100]))
                    except ValueError as e:
                        print(f"Skipping invalid row: {_row} -> Error: {e}")
        return _data
    except IOError as _err:
        print(f'File error: {_err}')
        exit()

def setOutputData(filename, results):
    with open(filename, 'w') as f:
        for target, matches in results.items():
            f.write(f"Target Hospital: {target}\n")
            seen = set()
            for match in sorted(matches, key=lambda x: -x[2]):
                matched_hospital = match[1]
                if matched_hospital in seen:
                    continue
                seen.add(matched_hospital)
                similarity = match[2]
                signature = match[3] if len(match) > 3 else []
                f.write(f"  Matched Hospital: {matched_hospital}, Jaccard Similarity: {similarity:.4f}, Signature: {signature[:10]}\n")

def jaccard_similarity(sig1, sig2):
    intersection = sum(1 for a, b in zip(sig1, sig2) if a == b)
    union = len(sig1)
    return intersection / union

def divide_into_bands(signature, bands, rows):
    for band in range(bands):
        start = band * rows
        end = start + rows
        yield band, tuple(signature[start:end])

if __name__ == "__main__":
    if PRINT_TIME:
        print(f'LSH=>Start=>{datetime.now()}')
    conf = SparkConf().setAppName(APP_NAME).setMaster("local[*]")
    sc = SparkContext(conf=conf)

    try:
        data_list = getInputData(INPUT_FILE)
        if not data_list:
            raise ValueError("No valid data loaded from the input file.")
    except Exception as e:
        print(f"Error loading input file: {e}")
        sc.stop()
        exit()

    rdd = sc.parallelize(data_list)

    def create_bands(hospital):
        hospital_id, signature = hospital
        bands = []
        for band, band_signature in divide_into_bands(signature, BANDS, ROWS):
            bands.append(((band, hash(band_signature)), hospital_id))
        return bands

    band_rdd = rdd.flatMap(create_bands)

    def candidate_pairs_generation(bucket):
        hospitals = list(bucket)
        for i, j in combinations(hospitals, 2):
            yield (i, j)

    candidates_rdd = band_rdd.groupByKey() \
        .filter(lambda x: len(x[1]) > 1) \
        .flatMap(lambda x: candidate_pairs_generation(x[1])).distinct()

    hospital_dict = dict(rdd.collect())

    def compute_similarity(pair):
        h1, h2 = pair
        if h1 in TARGET_HOSPITALS or h2 in TARGET_HOSPITALS:
            sig1 = hospital_dict[h1]
            sig2 = hospital_dict[h2]
            similarity = jaccard_similarity(sig1, sig2)
            return h1, h2, similarity, sig2[:10]
        return None

    results_rdd = candidates_rdd.map(compute_similarity).filter(lambda x: x is not None)

    def limit_candidates(results):
        sorted_results = sorted(results, key=lambda x: -x[2])
        return sorted_results[:NUM_CANDIDATES[1]]

    grouped_results = results_rdd.map(lambda x: (x[0] if x[0] in TARGET_HOSPITALS else x[1], x)) \
        .groupByKey() \
        .mapValues(limit_candidates).collectAsMap()

    print("Top Matches for Target Hospitals:")
    for target, matches in grouped_results.items():
        print(f"Target Hospital: {target}")
        seen = set()
        for match in sorted(matches, key=lambda x: -x[2]):
            matched_hospital = match[1]
            if matched_hospital in seen:
                continue
            seen.add(matched_hospital)
            print(f"  Matched Hospital: {matched_hospital}, Jaccard Similarity: {match[2]:.4f}, Signature: {match[3]}")

    setOutputData(OUTPUT_FILE, grouped_results)

    if PRINT_TIME:
        print(f'LSH=>Finish=>{datetime.now()}')
    sc.stop()
